# %% [markdown]
# Here is an example of a diagram:
#
# <figure>
# <center>
# <img src='https://drive.google.com/uc?id=16O7L5907dEj-LX3Xp9CGFqxQUjOD_j3Y'width='500px'/>
# <figcaption>"For" Loops vs "While" Loops</figcaption></center>
# </figure>
