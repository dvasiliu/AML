# %% [markdown]
# ## An Example of a Diagram
#
# <figure>
# <center>
# <img src='https://drive.google.com/uc?id=16O7L5907dEj-LX3Xp9CGFqxQUjOD_j3Y'width='500px'/>
# <figcaption>A Computational Diagram</figcaption></center>
# </figure>
